# %%
data = """ Jack and Jill went up the hill\n
To fetch a pail of water\n
Jack fell down and broke his crown\n
And Jill came tumbling after\n """

# %%
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Embedding

# %%
def generate_seq(model, tokenizer, max_length, seed_text, n_words):
    in_text = seed_text
    # generate a fixed number of words
    for _ in range(n_words):
        # encode the text as integer
        encoded = tokenizer.texts_to_sequences([in_text])[0]
        # pre-pad sequences to a fixed length
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')
        # predict probabilities for each word
        yhat = model.predict_classes(encoded, verbose=0)
        # map predicted word index to word
        out_word = ''
        for word, index in tokenizer.word_index.items():
            if index == yhat:
                out_word = word
                break
                # append to input
        in_text += ' ' + out_word
    return in_text

# %%
from keras.preprocessing.text import Tokenizer
tokenizer = Tokenizer()
tokenizer.fit_on_texts([data])
encoded = tokenizer.texts_to_sequences([data])[0]

# %%
sequences = list()
for i in range(2, len(encoded)):
    sequence = encoded[i-2:i+1]
    sequences.append(sequence)
print('Total Sequences: %d' % len(sequences))
# Out:
# Total Sequences: 23

# %%
from keras.preprocessing.sequence import pad_sequences
max_length = max([len(seq) for seq in sequences])
sequences = pad_sequences(sequences, maxlen=max_length, padding='pre')
print('Max Sequence Length: %d' % max_length)
# Out:
# Max Sequence Length: 3

# %%
vocab_size = len(tokenizer.word_index) + 1
print('Vocabulary Size: %d' % vocab_size)
# Out:
# Vocabulary Size: 22

# %%
import numpy as np
import pandas as pd
sequences = np.array(sequences)
X, y = sequences[:,:-1],sequences[:,-1]
y = to_categorical(y, num_classes=vocab_size)

# %%
def define_model(vocab_size, max_length):
    model = Sequential()
    model.add(Embedding(vocab_size, 10, input_length=max_length-1))
    model.add(LSTM(50))
    model.add(Dense(vocab_size, activation='softmax'))
    # compile network
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    # summarize defined model
    model.summary()
    plot_model(model, to_file='model.png', show_shapes=True)
    return model

# %%
model = define_model(vocab_size, max_length)
model.fit(X, y, epochs=200, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 2, 10)             220
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                12200
# _________________________________________________________________
# dense_1 (Dense)              (None, 22)                1122
# =================================================================
# Total params: 13,542
# Trainable params: 13,542
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 1/1 - 0s - loss: 3.0909 - accuracy: 0.0000e+00
# Epoch 2/200
# 1/1 - 0s - loss: 3.0900 - accuracy: 0.0870
# Epoch 3/200
# 1/1 - 0s - loss: 3.0891 - accuracy: 0.1304
# Epoch 4/200
# 1/1 - 0s - loss: 3.0882 - accuracy: 0.1304
# Epoch 5/200
# 1/1 - 0s - loss: 3.0873 - accuracy: 0.1304
# Epoch 6/200
# 1/1 - 0s - loss: 3.0864 - accuracy: 0.1304
# Epoch 7/200
# 1/1 - 0s - loss: 3.0854 - accuracy: 0.1304
# Epoch 8/200
# 1/1 - 0s - loss: 3.0845 - accuracy: 0.1304
# Epoch 9/200
# 1/1 - 0s - loss: 3.0835 - accuracy: 0.1304
# Epoch 10/200
# 1/1 - 0s - loss: 3.0826 - accuracy: 0.1304
# Epoch 11/200
# 1/1 - 0s - loss: 3.0816 - accuracy: 0.1304
# Epoch 12/200
# 1/1 - 0s - loss: 3.0805 - accuracy: 0.1304
# Epoch 13/200
# 1/1 - 0s - loss: 3.0795 - accuracy: 0.1304
# Epoch 14/200
# 1/1 - 0s - loss: 3.0784 - accuracy: 0.1304
# Epoch 15/200
# 1/1 - 0s - loss: 3.0773 - accuracy: 0.1304
# Epoch 16/200
# 1/1 - 0s - loss: 3.0762 - accuracy: 0.1304
# Epoch 17/200
# 1/1 - 0s - loss: 3.0751 - accuracy: 0.1304
# Epoch 18/200
# 1/1 - 0s - loss: 3.0739 - accuracy: 0.1304
# Epoch 19/200
# 1/1 - 0s - loss: 3.0727 - accuracy: 0.1304
# Epoch 20/200
# 1/1 - 0s - loss: 3.0714 - accuracy: 0.1304
# Epoch 21/200
# 1/1 - 0s - loss: 3.0701 - accuracy: 0.1304
# Epoch 22/200
# 1/1 - 0s - loss: 3.0688 - accuracy: 0.1304
# Epoch 23/200
# 1/1 - 0s - loss: 3.0674 - accuracy: 0.1304
# Epoch 24/200
# 1/1 - 0s - loss: 3.0659 - accuracy: 0.1304
# Epoch 25/200
# 1/1 - 0s - loss: 3.0645 - accuracy: 0.1304
# Epoch 26/200
# 1/1 - 0s - loss: 3.0629 - accuracy: 0.1304
# Epoch 27/200
# 1/1 - 0s - loss: 3.0614 - accuracy: 0.1304
# Epoch 28/200
# 1/1 - 0s - loss: 3.0597 - accuracy: 0.1304
# Epoch 29/200
# 1/1 - 0s - loss: 3.0580 - accuracy: 0.1304
# Epoch 30/200
# 1/1 - 0s - loss: 3.0563 - accuracy: 0.1304
# Epoch 31/200
# 1/1 - 0s - loss: 3.0544 - accuracy: 0.1304
# Epoch 32/200
# 1/1 - 0s - loss: 3.0525 - accuracy: 0.1304
# Epoch 33/200
# 1/1 - 0s - loss: 3.0506 - accuracy: 0.1304
# Epoch 34/200
# 1/1 - 0s - loss: 3.0485 - accuracy: 0.1304
# Epoch 35/200
# 1/1 - 0s - loss: 3.0464 - accuracy: 0.1304
# Epoch 36/200
# 1/1 - 0s - loss: 3.0442 - accuracy: 0.1304
# Epoch 37/200
# 1/1 - 0s - loss: 3.0420 - accuracy: 0.1304
# Epoch 38/200
# 1/1 - 0s - loss: 3.0396 - accuracy: 0.1304
# Epoch 39/200
# 1/1 - 0s - loss: 3.0372 - accuracy: 0.1304
# Epoch 40/200
# 1/1 - 0s - loss: 3.0346 - accuracy: 0.1304
# Epoch 41/200
# 1/1 - 0s - loss: 3.0320 - accuracy: 0.1304
# Epoch 42/200
# 1/1 - 0s - loss: 3.0292 - accuracy: 0.1304
# Epoch 43/200
# 1/1 - 0s - loss: 3.0264 - accuracy: 0.1304
# Epoch 44/200
# 1/1 - 0s - loss: 3.0234 - accuracy: 0.1304
# Epoch 45/200
# 1/1 - 0s - loss: 3.0203 - accuracy: 0.1304
# Epoch 46/200
# 1/1 - 0s - loss: 3.0171 - accuracy: 0.1304
# Epoch 47/200
# 1/1 - 0s - loss: 3.0138 - accuracy: 0.1304
# Epoch 48/200
# 1/1 - 0s - loss: 3.0103 - accuracy: 0.1304
# Epoch 49/200
# 1/1 - 0s - loss: 3.0067 - accuracy: 0.1304
# Epoch 50/200
# 1/1 - 0s - loss: 3.0030 - accuracy: 0.1304
# Epoch 51/200
# 1/1 - 0s - loss: 2.9991 - accuracy: 0.1304
# Epoch 52/200
# 1/1 - 0s - loss: 2.9950 - accuracy: 0.1304
# Epoch 53/200
# 1/1 - 0s - loss: 2.9908 - accuracy: 0.1304
# Epoch 54/200
# 1/1 - 0s - loss: 2.9864 - accuracy: 0.1304
# Epoch 55/200
# 1/1 - 0s - loss: 2.9819 - accuracy: 0.1304
# Epoch 56/200
# 1/1 - 0s - loss: 2.9772 - accuracy: 0.1304
# Epoch 57/200
# 1/1 - 0s - loss: 2.9723 - accuracy: 0.1304
# Epoch 58/200
# 1/1 - 0s - loss: 2.9671 - accuracy: 0.1304
# Epoch 59/200
# 1/1 - 0s - loss: 2.9618 - accuracy: 0.1304
# Epoch 60/200
# 1/1 - 0s - loss: 2.9563 - accuracy: 0.1304
# Epoch 61/200
# 1/1 - 0s - loss: 2.9506 - accuracy: 0.1304
# Epoch 62/200
# 1/1 - 0s - loss: 2.9446 - accuracy: 0.1304
# Epoch 63/200
# 1/1 - 0s - loss: 2.9384 - accuracy: 0.1304
# Epoch 64/200
# 1/1 - 0s - loss: 2.9320 - accuracy: 0.1304
# Epoch 65/200
# 1/1 - 0s - loss: 2.9253 - accuracy: 0.1304
# Epoch 66/200
# 1/1 - 0s - loss: 2.9183 - accuracy: 0.1304
# Epoch 67/200
# 1/1 - 0s - loss: 2.9111 - accuracy: 0.1304
# Epoch 68/200
# 1/1 - 0s - loss: 2.9036 - accuracy: 0.1304
# Epoch 69/200
# 1/1 - 0s - loss: 2.8958 - accuracy: 0.1304
# Epoch 70/200
# 1/1 - 0s - loss: 2.8877 - accuracy: 0.1304
# Epoch 71/200
# 1/1 - 0s - loss: 2.8793 - accuracy: 0.1304
# Epoch 72/200
# 1/1 - 0s - loss: 2.8707 - accuracy: 0.1304
# Epoch 73/200
# 1/1 - 0s - loss: 2.8617 - accuracy: 0.1304
# Epoch 74/200
# 1/1 - 0s - loss: 2.8523 - accuracy: 0.1304
# Epoch 75/200
# 1/1 - 0s - loss: 2.8427 - accuracy: 0.1304
# Epoch 76/200
# 1/1 - 0s - loss: 2.8327 - accuracy: 0.1304
# Epoch 77/200
# 1/1 - 0s - loss: 2.8223 - accuracy: 0.1304
# Epoch 78/200
# 1/1 - 0s - loss: 2.8116 - accuracy: 0.1304
# Epoch 79/200
# 1/1 - 0s - loss: 2.8005 - accuracy: 0.1304
# Epoch 80/200
# 1/1 - 0s - loss: 2.7891 - accuracy: 0.1304
# Epoch 81/200
# 1/1 - 0s - loss: 2.7773 - accuracy: 0.1304
# Epoch 82/200
# 1/1 - 0s - loss: 2.7652 - accuracy: 0.1304
# Epoch 83/200
# 1/1 - 0s - loss: 2.7526 - accuracy: 0.1304
# Epoch 84/200
# 1/1 - 0s - loss: 2.7397 - accuracy: 0.1304
# Epoch 85/200
# 1/1 - 0s - loss: 2.7264 - accuracy: 0.1304
# Epoch 86/200
# 1/1 - 0s - loss: 2.7127 - accuracy: 0.1304
# Epoch 87/200
# 1/1 - 0s - loss: 2.6986 - accuracy: 0.1304
# Epoch 88/200
# 1/1 - 0s - loss: 2.6842 - accuracy: 0.1304
# Epoch 89/200
# 1/1 - 0s - loss: 2.6693 - accuracy: 0.1304
# Epoch 90/200
# 1/1 - 0s - loss: 2.6541 - accuracy: 0.1739
# Epoch 91/200
# 1/1 - 0s - loss: 2.6385 - accuracy: 0.1739
# Epoch 92/200
# 1/1 - 0s - loss: 2.6225 - accuracy: 0.2174
# Epoch 93/200
# 1/1 - 0s - loss: 2.6061 - accuracy: 0.2174
# Epoch 94/200
# 1/1 - 0s - loss: 2.5893 - accuracy: 0.2609
# Epoch 95/200
# 1/1 - 0s - loss: 2.5722 - accuracy: 0.2609
# Epoch 96/200
# 1/1 - 0s - loss: 2.5547 - accuracy: 0.2609
# Epoch 97/200
# 1/1 - 0s - loss: 2.5369 - accuracy: 0.3043
# Epoch 98/200
# 1/1 - 0s - loss: 2.5187 - accuracy: 0.3043
# Epoch 99/200
# 1/1 - 0s - loss: 2.5001 - accuracy: 0.3043
# Epoch 100/200
# 1/1 - 0s - loss: 2.4813 - accuracy: 0.3043
# Epoch 101/200
# 1/1 - 0s - loss: 2.4621 - accuracy: 0.3043
# Epoch 102/200
# 1/1 - 0s - loss: 2.4426 - accuracy: 0.3043
# Epoch 103/200
# 1/1 - 0s - loss: 2.4228 - accuracy: 0.3043
# Epoch 104/200
# 1/1 - 0s - loss: 2.4027 - accuracy: 0.3043
# Epoch 105/200
# 1/1 - 0s - loss: 2.3824 - accuracy: 0.3043
# Epoch 106/200
# 1/1 - 0s - loss: 2.3618 - accuracy: 0.3043
# Epoch 107/200
# 1/1 - 0s - loss: 2.3410 - accuracy: 0.3043
# Epoch 108/200
# 1/1 - 0s - loss: 2.3199 - accuracy: 0.3478
# Epoch 109/200
# 1/1 - 0s - loss: 2.2987 - accuracy: 0.3913
# Epoch 110/200
# 1/1 - 0s - loss: 2.2772 - accuracy: 0.3913
# Epoch 111/200
# 1/1 - 0s - loss: 2.2556 - accuracy: 0.4348
# Epoch 112/200
# 1/1 - 0s - loss: 2.2339 - accuracy: 0.4348
# Epoch 113/200
# 1/1 - 0s - loss: 2.2119 - accuracy: 0.4348
# Epoch 114/200
# 1/1 - 0s - loss: 2.1899 - accuracy: 0.4348
# Epoch 115/200
# 1/1 - 0s - loss: 2.1677 - accuracy: 0.4348
# Epoch 116/200
# 1/1 - 0s - loss: 2.1453 - accuracy: 0.4348
# Epoch 117/200
# 1/1 - 0s - loss: 2.1229 - accuracy: 0.4348
# Epoch 118/200
# 1/1 - 0s - loss: 2.1004 - accuracy: 0.4348
# Epoch 119/200
# 1/1 - 0s - loss: 2.0777 - accuracy: 0.4348
# Epoch 120/200
# 1/1 - 0s - loss: 2.0550 - accuracy: 0.4348
# Epoch 121/200
# 1/1 - 0s - loss: 2.0322 - accuracy: 0.4348
# Epoch 122/200
# 1/1 - 0s - loss: 2.0093 - accuracy: 0.4348
# Epoch 123/200
# 1/1 - 0s - loss: 1.9863 - accuracy: 0.4348
# Epoch 124/200
# 1/1 - 0s - loss: 1.9632 - accuracy: 0.4783
# Epoch 125/200
# 1/1 - 0s - loss: 1.9401 - accuracy: 0.4783
# Epoch 126/200
# 1/1 - 0s - loss: 1.9169 - accuracy: 0.5217
# Epoch 127/200
# 1/1 - 0s - loss: 1.8936 - accuracy: 0.5217
# Epoch 128/200
# 1/1 - 0s - loss: 1.8702 - accuracy: 0.5652
# Epoch 129/200
# 1/1 - 0s - loss: 1.8468 - accuracy: 0.5652
# Epoch 130/200
# 1/1 - 0s - loss: 1.8233 - accuracy: 0.6087
# Epoch 131/200
# 1/1 - 0s - loss: 1.7997 - accuracy: 0.6522
# Epoch 132/200
# 1/1 - 0s - loss: 1.7761 - accuracy: 0.6522
# Epoch 133/200
# 1/1 - 0s - loss: 1.7524 - accuracy: 0.6522
# Epoch 134/200
# 1/1 - 0s - loss: 1.7286 - accuracy: 0.6522
# Epoch 135/200
# 1/1 - 0s - loss: 1.7048 - accuracy: 0.6522
# Epoch 136/200
# 1/1 - 0s - loss: 1.6810 - accuracy: 0.6957
# Epoch 137/200
# 1/1 - 0s - loss: 1.6570 - accuracy: 0.6957
# Epoch 138/200
# 1/1 - 0s - loss: 1.6330 - accuracy: 0.7391
# Epoch 139/200
# 1/1 - 0s - loss: 1.6090 - accuracy: 0.7391
# Epoch 140/200
# 1/1 - 0s - loss: 1.5849 - accuracy: 0.7391
# Epoch 141/200
# 1/1 - 0s - loss: 1.5608 - accuracy: 0.7391
# Epoch 142/200
# 1/1 - 0s - loss: 1.5367 - accuracy: 0.7391
# Epoch 143/200
# 1/1 - 0s - loss: 1.5125 - accuracy: 0.7391
# Epoch 144/200
# 1/1 - 0s - loss: 1.4883 - accuracy: 0.7391
# Epoch 145/200
# 1/1 - 0s - loss: 1.4642 - accuracy: 0.7391
# Epoch 146/200
# 1/1 - 0s - loss: 1.4400 - accuracy: 0.7391
# Epoch 147/200
# 1/1 - 0s - loss: 1.4158 - accuracy: 0.8696
# Epoch 148/200
# 1/1 - 0s - loss: 1.3916 - accuracy: 0.8696
# Epoch 149/200
# 1/1 - 0s - loss: 1.3674 - accuracy: 0.8696
# Epoch 150/200
# 1/1 - 0s - loss: 1.3433 - accuracy: 0.8696
# Epoch 151/200
# 1/1 - 0s - loss: 1.3192 - accuracy: 0.8696
# Epoch 152/200
# 1/1 - 0s - loss: 1.2952 - accuracy: 0.8696
# Epoch 153/200
# 1/1 - 0s - loss: 1.2713 - accuracy: 0.9130
# Epoch 154/200
# 1/1 - 0s - loss: 1.2474 - accuracy: 0.9130
# Epoch 155/200
# 1/1 - 0s - loss: 1.2236 - accuracy: 0.9130
# Epoch 156/200
# 1/1 - 0s - loss: 1.2000 - accuracy: 0.9130
# Epoch 157/200
# 1/1 - 0s - loss: 1.1764 - accuracy: 0.9130
# Epoch 158/200
# 1/1 - 0s - loss: 1.1530 - accuracy: 0.9130
# Epoch 159/200
# 1/1 - 0s - loss: 1.1297 - accuracy: 0.9130
# Epoch 160/200
# 1/1 - 0s - loss: 1.1066 - accuracy: 0.9130
# Epoch 161/200
# 1/1 - 0s - loss: 1.0836 - accuracy: 0.9130
# Epoch 162/200
# 1/1 - 0s - loss: 1.0609 - accuracy: 0.9130
# Epoch 163/200
# 1/1 - 0s - loss: 1.0383 - accuracy: 0.9130
# Epoch 164/200
# 1/1 - 0s - loss: 1.0159 - accuracy: 0.9130
# Epoch 165/200
# 1/1 - 0s - loss: 0.9938 - accuracy: 0.9130
# Epoch 166/200
# 1/1 - 0s - loss: 0.9719 - accuracy: 0.9130
# Epoch 167/200
# 1/1 - 0s - loss: 0.9503 - accuracy: 0.9130
# Epoch 168/200
# 1/1 - 0s - loss: 0.9289 - accuracy: 0.9130
# Epoch 169/200
# 1/1 - 0s - loss: 0.9078 - accuracy: 0.9565
# Epoch 170/200
# 1/1 - 0s - loss: 0.8870 - accuracy: 0.9565
# Epoch 171/200
# 1/1 - 0s - loss: 0.8665 - accuracy: 0.9565
# Epoch 172/200
# 1/1 - 0s - loss: 0.8463 - accuracy: 0.9565
# Epoch 173/200
# 1/1 - 0s - loss: 0.8264 - accuracy: 0.9565
# Epoch 174/200
# 1/1 - 0s - loss: 0.8068 - accuracy: 0.9565
# Epoch 175/200
# 1/1 - 0s - loss: 0.7876 - accuracy: 0.9565
# Epoch 176/200
# 1/1 - 0s - loss: 0.7687 - accuracy: 0.9565
# Epoch 177/200
# 1/1 - 0s - loss: 0.7502 - accuracy: 0.9565
# Epoch 178/200
# 1/1 - 0s - loss: 0.7320 - accuracy: 0.9565
# Epoch 179/200
# 1/1 - 0s - loss: 0.7142 - accuracy: 0.9565
# Epoch 180/200
# 1/1 - 0s - loss: 0.6968 - accuracy: 0.9565
# Epoch 181/200
# 1/1 - 0s - loss: 0.6797 - accuracy: 0.9565
# Epoch 182/200
# 1/1 - 0s - loss: 0.6630 - accuracy: 0.9565
# Epoch 183/200
# 1/1 - 0s - loss: 0.6467 - accuracy: 0.9565
# Epoch 184/200
# 1/1 - 0s - loss: 0.6307 - accuracy: 0.9565
# Epoch 185/200
# 1/1 - 0s - loss: 0.6152 - accuracy: 0.9565
# Epoch 186/200
# 1/1 - 0s - loss: 0.6000 - accuracy: 0.9565
# Epoch 187/200
# 1/1 - 0s - loss: 0.5851 - accuracy: 0.9565
# Epoch 188/200
# 1/1 - 0s - loss: 0.5707 - accuracy: 0.9565
# Epoch 189/200
# 1/1 - 0s - loss: 0.5566 - accuracy: 0.9565
# Epoch 190/200
# 1/1 - 0s - loss: 0.5428 - accuracy: 0.9565
# Epoch 191/200
# 1/1 - 0s - loss: 0.5294 - accuracy: 0.9565
# Epoch 192/200
# 1/1 - 0s - loss: 0.5164 - accuracy: 0.9565
# Epoch 193/200
# 1/1 - 0s - loss: 0.5037 - accuracy: 0.9565
# Epoch 194/200
# 1/1 - 0s - loss: 0.4913 - accuracy: 0.9565
# Epoch 195/200
# 1/1 - 0s - loss: 0.4793 - accuracy: 0.9565
# Epoch 196/200
# 1/1 - 0s - loss: 0.4676 - accuracy: 0.9565
# Epoch 197/200
# 1/1 - 0s - loss: 0.4562 - accuracy: 0.9565
# Epoch 198/200
# 1/1 - 0s - loss: 0.4452 - accuracy: 0.9565
# Epoch 199/200
# 1/1 - 0s - loss: 0.4344 - accuracy: 0.9565
# Epoch 200/200
# 1/1 - 0s - loss: 0.4240 - accuracy: 0.9565

# %%
print(generate_seq(model, tokenizer, max_length-1, 'Jack and', 1))
print(generate_seq(model, tokenizer, max_length-1, 'And Jill', 3))
print(generate_seq(model, tokenizer, max_length-1, 'fell down', 5))
print(generate_seq(model, tokenizer, max_length-1, 'pail of', 5))
# Out:
# Jack and jill
# And Jill went up the
# fell down and broke his crown and
# pail of water jack fell down and
